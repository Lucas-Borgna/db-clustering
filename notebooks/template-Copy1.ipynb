# %%
### Reloads modules properly
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.sys.path.append('../')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mplhep as hep
hep.style.use('CMS')

# %%
trk = pd.read_pickle('/mnt/storage/lborgna/track/l1_nnt/trk_25k.pkl')

# %%
e1 = trk.query('entry == 0')

# %%
y =e1.shape[0]*[1]

# %%
fig, ax = plt.subplots(figsize=(20, 5))
ax.plot(e1.trk_z0, y, '|', markersize = 100, lw=2)
ax.set_yticks([])
ax.set_xlabel(r'$z_{0}$ [cm]')
ax.set_title('Track clustering')
# Out:
# Text(0.5, 1.0, 'Track clustering')
