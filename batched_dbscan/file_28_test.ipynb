# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from math import isclose

np.random.seed(42)

pd.set_option("display.precision", 2)

def run_normal_dbscan(z0, pt, eps):
    dfb = pd.DataFrame({"z0": z0, "pt": pt})
    db = DBSCAN(eps=eps, min_samples=2).fit(dfb["z0"].values.reshape(-1, 1))
    dfb["label"] = db.labels_

    dfb.loc[dfb.label == -1, "pt"] = 0

    clusters = dfb.groupby("label").agg({"z0": [np.median], "pt": [np.sum]})
    clusters.columns = ["z0", "pt_sum"]

    clusters = clusters.sort_values(by="pt_sum", ascending=False)

    z0_pv = clusters.iloc[0]["z0"]
    pt_pv = clusters.iloc[0]["pt_sum"]

    return z0_pv, pt_pv, clusters


if __name__ == "__main__":

    max_number_of_tracks = 232
    max_number_of_tracks_power_2 = 256
    max_number_of_tracks_log_2 = 8
    batch_size = 50

    eps = 0.15
    verbose = False
    save_intermediate = False
    from batched_dbscan import BatchedDBSCAN

    z0_pvs = []
    z0_batched = []
    z0_batched_skl = []
    pt_pvs = []
    pt_batched = []
    pt_batched_skl = []
    file_i = 28

    store = "/home/kirby/data/binaries-trk-100/"
    z0_file = store + f"b-{file_i}-trk-z0.bin"
    pt_file = store + f"b-{file_i}-trk-pt.bin"
    z0 = np.fromfile(z0_file, dtype=np.float32)
    pt = np.fromfile(pt_file, dtype=np.float32)

    z0_pv, pt_pv, clusters = run_normal_dbscan(z0, pt, eps)

    db = BatchedDBSCAN(
        z0, pt, eps, batch_size, max_number_of_tracks, verbose, save_intermediate
    )

    db.fit()

    db_skl = BatchedDBSCAN(
        z0, pt, eps, batch_size, max_number_of_tracks, verbose, save_intermediate
    )

    db_skl.fitsklearn()

    z0_pvs.append(z0_pv)
    z0_batched.append(db.z0_pv)
    z0_batched_skl.append(db_skl.z0_pv_skl)
    pt_pvs.append(pt_pv)
    pt_batched.append(db.max_pt)
    pt_batched_skl.append(db_skl.max_pt)

    r = pd.DataFrame(
        {
            "z0_normal": z0_pvs,
            "z0_batched": z0_batched,
            "z0_batched_skl": z0_batched_skl,
            "pt_normal": pt_pvs,
            "pt_batched": pt_batched,
            "pt_batched_skl": pt_batched_skl,
        }
    )
    print(r)
    d = pd.DataFrame({})


    d['z0_diff'] = 100 * (r['z0_batched'] - r['z0_normal']) / r['z0_normal']
    d['pt_diff'] = 100 * (r['pt_batched'] - r['pt_normal']) / r['pt_normal']
    pd.set_option('display.max_columns', None)
    print(d)
    print(clusters)

    # print(d.describe())
    # print(
    #     f"file {i}: {db.z0_pv} ({db_skl.z0_pv_skl}), {db.max_pt} ({db_skl.max_pt})"
    # )
    # print(db.boundaries_batches[0])
    # print(db.z0_pv, db.max_pt)

    # import json
    # with open('merged_list.json', 'w') as f:
    #     json.dump(db.merged_list, f, indent=4)
# Out:
# (250,)
#    z0_normal  z0_batched  z0_batched_skl  pt_normal  pt_batched  \
# 0        0.0         0.0             0.0     244.23      244.23
#
#    pt_batched_skl
# 0          244.23
#    z0_diff   pt_diff
# 0      NaN -5.37e-07
#          z0  pt_sum
# label
#  5     0.00  244.23
#  2     3.57   46.59
#  1     5.68   42.40
#  0    -6.09   31.37
#  10    1.76   27.30
#  6     4.34   23.89
#  4    -5.33   19.19
#  9    -2.29   18.78
#  15   -3.63   16.41
#  21    2.11   11.99
#  7     2.87   10.94
#  14   -4.86   10.89
#  8    -2.81    9.47
#  3     1.00    7.84
#  11   -1.41    6.57
#  18    1.35    6.45
#  13    4.86    4.86
#  16    8.00    4.80
#  19   -7.62    4.77
#  20    2.46    4.47
#  12    3.08    4.32
#  17   -3.90    4.18
#  22   -1.79    3.95
# -1    -5.62    0.00

# %%
db.boundaries_batches[0].shape
# Out:
# (50, 7)

# %%
def compare_boundaries(b_t, b_c):
    columns = ['idx','pts','nextPts','z0_low','z0_high','noise']

    for col in columns:
        for i in range(b_t.shape[0]):
            a = b_t[col].iloc[i]
            b = b_c[col].iloc[i]
            if not isclose(a, b, rel_tol=1e-5):
                print(f'column {col} at index {i} is different')
                print(f'batched: {b_t[col].iloc[i]}')
                print(f'c++: {b_c[col].iloc[i]}')
                print()

# %%
for i in range(5):
    print(f"--------------- batch number {i} ----------------")
    b_t = pd.DataFrame(db.boundaries_batches[i], columns = ['idx', 'pts','nextPts','rSum','z0_low','z0_high','noise'])
    b_t.drop(columns=['rSum'],inplace=True)
    b_c = pd.read_csv(f'file28/boundaries-{i}.txt', sep=', ', names = ['idx','pts','nextPts','z0_low','z0_high','noise'], engine ='python')
    compare_boundaries(b_t, b_c)
# Out:
# --------------- batch number 0 ----------------
# column pts at index 12 is different
# batched: 43.295854806900024
# c++: 43.9405
#
# column noise at index 36 is different
# batched: 0.0
# c++: 1
#
# --------------- batch number 1 ----------------
# column nextPts at index 13 is different
# batched: 45.883562445640564
# c++: 45.7556
#
# --------------- batch number 2 ----------------
# column pts at index 8 is different
# batched: 25.87757134437561
# c++: 26.1029
#
# column nextPts at index 7 is different
# batched: 20.630732536315918
# c++: 21.1231
#
# column nextPts at index 18 is different
# batched: 57.11890172958374
# c++: 56.1091
#
# column nextPts at index 20 is different
# batched: 64.86072564125061
# c++: 63.9775
#
# --------------- batch number 3 ----------------
# column pts at index 15 is different
# batched: 69.73574566841125
# c++: 71.3885
#
# column pts at index 17 is different
# batched: 75.30391371250153
# c++: 75.5334
#
# column pts at index 29 is different
# batched: 129.7069798707962
# c++: 131.066
#
# column nextPts at index 16 is different
# batched: 75.30391371250153
# c++: 75.5334
#
# --------------- batch number 4 ----------------
# column idx at index 2 is different
# batched: 2.0
# c++: 18
#
# column idx at index 3 is different
# batched: 3.0
# c++: 19
#
# column idx at index 4 is different
# batched: 49.0
# c++: 20
#
# column idx at index 5 is different
# batched: 50.0
# c++: 21
#
# column idx at index 6 is different
# batched: 50.0
# c++: 49
#
# column pts at index 2 is different
# batched: 4.913720369338989
# c++: 2.04721
#
# column pts at index 3 is different
# batched: 7.963721752166748
# c++: 2.04721
#
# column pts at index 4 is different
# batched: 7.963721752166748
# c++: 4.91372
#
# column pts at index 5 is different
# batched: 0.0
# c++: 7.96372
#
# column pts at index 6 is different
# batched: 0.0
# c++: 7.96372
#
# column nextPts at index 1 is different
# batched: 4.913720369338989
# c++: 2.04721
#
# column nextPts at index 2 is different
# batched: 7.963721752166748
# c++: 2.04721
#
# column nextPts at index 3 is different
# batched: 7.963721752166748
# c++: 4.91372
#
# column nextPts at index 5 is different
# batched: 0.0
# c++: 7.96372
#
# column nextPts at index 6 is different
# batched: 0.0
# c++: 7.96372
#
# column z0_low at index 1 is different
# batched: 1.7578125
# c++: 0.0
#
# column z0_low at index 2 is different
# batched: 2.87109375
# c++: 0.0
#
# column z0_low at index 3 is different
# batched: 21.0
# c++: 1.75781
#
# column z0_low at index 4 is different
# batched: 21.0
# c++: 2.87109
#
# column z0_high at index 1 is different
# batched: 1.7578125
# c++: 0.0
#
# column z0_high at index 2 is different
# batched: 2.87109375
# c++: 1.75781
#
# column z0_high at index 3 is different
# batched: 21.0
# c++: 1.75781
#
# column z0_high at index 4 is different
# batched: 21.0
# c++: 2.87109
#
# column noise at index 1 is different
# batched: 1.0
# c++: 0
#
# column noise at index 2 is different
# batched: 1.0
# c++: 0
#
# column noise at index 3 is different
# batched: 0.0
# c++: 1
#
# column noise at index 4 is different
# batched: 0.0
# c++: 1
#
# column noise at index 6 is different
# batched: 0.0
# c++: 1

# %%
rs0 = np.genfromtxt('file28/rs-0.txt', delimiter=' ')

# %%
np.array_equal(db.rs_batches[0], rs0)
# Out:
# False

# %%
for i in range(len(rs0)):
    a = rs0[i]
    b = db.rs_batches[0][i]
    if not isclose(a, b, rel_tol=1e-5):
        print(f'rs at index {i} is different')
        print(f'batched: {b}')
        print(f'c++: {a}')
        print()
# Out:
# rs at index 17 is different
# batched: 43.295854806900024
# c++: 43.9405

# %%
def compare_rs(r_t, r_c):
    for i in range(r_t.shape[0]):
        a = r_t[i]
        b = r_c[i]
        if not isclose(a, b, rel_tol=1e-5):
            print(f'rs at index {i} is different')
            print(f'batched: {b}')
            print(f'c++: {a}')
            print()

# %%
for i in range(5):
    print(f"--------------- batch number {i} ----------------")
    r_t = db.rs_batches[i]
    r_c = np.genfromtxt(f'file28/rs-{i}.txt', delimiter=' ')
    compare_rs(r_t, r_c)
# Out:
# --------------- batch number 0 ----------------
# rs at index 17 is different
# batched: 43.9405
# c++: 43.295854806900024
#
# --------------- batch number 1 ----------------
# rs at index 16 is different
# batched: 45.7556
# c++: 45.883562445640564
#
# rs at index 20 is different
# batched: 58.8261
# c++: 60.62415421009064
#
# rs at index 25 is different
# batched: 75.7804
# c++: 84.01855981349945
#
# rs at index 29 is different
# batched: 95.535
# c++: 99.03739178180695
#
# rs at index 34 is different
# batched: 112.11
# c++: 110.67035496234894
#
# --------------- batch number 2 ----------------
# rs at index 8 is different
# batched: 21.1231
# c++: 20.630732536315918
#
# rs at index 10 is different
# batched: 26.1029
# c++: 25.87757134437561
#
# rs at index 21 is different
# batched: 56.1091
# c++: 57.11890172958374
#
# rs at index 24 is different
# batched: 63.9775
# c++: 64.86072564125061
#
# rs at index 25 is different
# batched: 66.9231
# c++: 67.41643571853638
#
# rs at index 26 is different
# batched: 69.3408
# c++: 69.54733872413635
#
# rs at index 27 is different
# batched: 71.4717
# c++: 71.6097583770752
#
# rs at index 28 is different
# batched: 74.7917
# c++: 74.92973589897156
#
# --------------- batch number 3 ----------------
# rs at index 17 is different
# batched: 52.2841
# c++: 51.69176721572876
#
# rs at index 21 is different
# batched: 65.2457
# c++: 62.223604679107666
#
# rs at index 23 is different
# batched: 71.3885
# c++: 69.73574566841125
#
# rs at index 25 is different
# batched: 75.5334
# c++: 75.30391371250153
#
# rs at index 41 is different
# batched: 131.066
# c++: 129.7069798707962
#
# --------------- batch number 4 ----------------
# rs at index 2 is different
# batched: 2.04721
# c++: 4.913720369338989
#
# rs at index 3 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 4 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 5 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 6 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 7 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 8 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 9 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 10 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 11 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 12 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 13 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 14 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 15 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 16 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 17 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 18 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 19 is different
# batched: 2.04721
# c++: 7.963721752166748
#
# rs at index 20 is different
# batched: 4.91372
# c++: 7.963721752166748

# %%
db.rs_batches[0]
# Out:
# array([  0.  ,   2.72,   4.71,   7.83,  10.58,  13.74,  15.8 ,  18.14,
#         21.16,  23.13,  26.76,  29.71,  32.24,  34.39,  36.48,  38.65,
#         41.04,  43.3 ,  46.19,  49.41,  52.63,  55.31,  57.57,  59.67,
#         62.4 ,  75.73,  78.73,  81.26,  83.33,  85.95,  88.  ,  91.93,
#         94.36,  99.92, 102.25, 104.42, 106.41, 108.99, 112.  , 114.94,
#        116.99, 120.12, 122.14, 124.44, 127.08, 129.77, 132.61, 134.73,
#        137.25, 139.7 , 143.13, 143.13, 143.13, 143.13, 143.13, 143.13,
#        143.13, 143.13, 143.13, 143.13, 143.13, 143.13, 143.13, 143.13])

# %%
pd.read_csv('file28/rs-0.txt', sep=' ', header=None).values
# Out:
# array([[  0.  ,   2.72,   4.71,   7.83,  10.58,  13.74,  15.8 ,  18.14,
#          21.16,  23.13,  26.76,  29.71,  32.24,  34.39,  36.48,  38.65,
#          41.04,  43.94,  46.19,  49.41,  52.63,  55.31,  57.57,  59.67,
#          62.4 ,  75.73,  78.73,  81.26,  83.33,  85.95,  88.  ,  91.93,
#          94.36,  99.92, 102.25, 104.42, 106.41, 108.99, 112.  , 114.94,
#         117.  , 120.12, 122.14, 124.44, 127.08, 129.77, 132.61, 134.73,
#         137.25, 139.7 , 143.13, 143.13, 143.13, 143.13, 143.13, 143.13,
#         143.13, 143.13, 143.13, 143.13, 143.13, 143.13, 143.13, 143.13,
#            nan]])

# %% [markdown]
# ### Looking at the tracks

# %%
tc = pd.read_csv('file28/tracks-1.txt', sep=', ', names = ['z0','pt'], engine='python')

# %%
db.z0_batches[0]
# Out:
# array([-6.21, -6.09, -6.09, -5.8 , -5.39, -4.45, -2.87, -2.29, -1.99,
#        -1.46, -1.35, -1.  , -0.76, -0.7 , -0.64, -0.59, -0.47, -0.47,
#        -0.18, -0.06,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.18,  0.29,
#         0.29,  0.7 ,  0.76,  1.  ,  1.76,  2.87,  2.87,  3.05,  3.52,
#         3.57,  3.69,  3.75,  3.98,  4.28,  4.45,  4.45,  4.92,  5.39,
#         5.51,  5.68,  5.74,  6.09,  6.15])

# %%
tc['z0py'] = db.z0_batches[1]
tc['ptpy'] = db.pt_batches[1]

# %%
tc0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kirby/Documents/db-clustering/batched_dbscan/file_28_test.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B139.162.234.225/home/kirby/Documents/db-clustering/batched_dbscan/file_28_test.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> tc0
#
# NameError: name 'tc0' is not defined

# %%
def compare_tracks(t_t, t_c):
    columns = ['z0','pt']

    for col in columns:
        for i in range(t_t.shape[0]):
            a = t_t[col].iloc[i]
            b = t_c[col].iloc[i]
            if not isclose(a, b, rel_tol=1e-5):
                print(f'column {col} at index {i} is different')
                print(f'batched: {t_t[col].iloc[i]}')
                print(f'c++: {t_c[col].iloc[i]}')
                print()

# %%
for i in range(5):
    t_c = pd.read_csv("file28/tracks-{}.txt".format(i), sep=', ', names = ['z0','pt'], engine='python')
    t_t = pd.DataFrame({'z0': db.z0_batches[i], 'pt': db.pt_batches[i]})
    print(f"--------------- batch number {i} ----------------")
    compare_tracks(t_t, t_c)
# Out:
# --------------- batch number 0 ----------------
# column pt at index 16 is different
# batched: 2.2510147094726562
# c++: 2.89567
#
# column pt at index 17 is different
# batched: 2.8956716060638428
# c++: 2.25101
#
# --------------- batch number 1 ----------------
# column pt at index 15 is different
# batched: 2.237856149673462
# c++: 2.10985
#
# column pt at index 16 is different
# batched: 2.1098451614379883
# c++: 2.23786
#
# column pt at index 19 is different
# batched: 5.363287448883057
# c++: 3.56519
#
# column pt at index 20 is different
# batched: 3.5651910305023193
# c++: 5.36329
#
# column pt at index 24 is different
# batched: 12.615914344787598
# c++: 4.37776
#
# column pt at index 25 is different
# batched: 4.377762317657471
# c++: 12.6159
#
# column pt at index 28 is different
# batched: 6.120179653167725
# c++: 2.61778
#
# column pt at index 29 is different
# batched: 2.6177799701690674
# c++: 6.12018
#
# column pt at index 33 is different
# batched: 2.1391146183013916
# c++: 3.57898
#
# column pt at index 34 is different
# batched: 3.5789828300476074
# c++: 2.13911
#
# --------------- batch number 2 ----------------
# column pt at index 7 is different
# batched: 2.723749876022339
# c++: 3.21611
#
# column pt at index 8 is different
# batched: 3.2161080837249756
# c++: 2.72375
#
# column pt at index 9 is different
# batched: 2.030730724334717
# c++: 2.25605
#
# column pt at index 10 is different
# batched: 2.2560465335845947
# c++: 2.03073
#
# column pt at index 20 is different
# batched: 3.836214542388916
# c++: 2.82638
#
# column pt at index 21 is different
# batched: 2.826375961303711
# c++: 3.83621
#
# column pt at index 23 is different
# batched: 2.945610284805298
# c++: 2.06242
#
# column pt at index 24 is different
# batched: 2.5557100772857666
# c++: 2.94561
#
# column pt at index 25 is different
# batched: 2.1309030055999756
# c++: 2.41768
#
# column pt at index 26 is different
# batched: 2.0624196529388428
# c++: 2.1309
#
# column pt at index 28 is different
# batched: 2.4176840782165527
# c++: 2.55571
#
# --------------- batch number 3 ----------------
# column pt at index 16 is different
# batched: 2.1971118450164795
# c++: 2.78945
#
# column pt at index 17 is different
# batched: 2.7894484996795654
# c++: 2.19711
#
# column pt at index 20 is different
# batched: 2.528930425643921
# c++: 5.551
#
# column pt at index 21 is different
# batched: 5.551002502441406
# c++: 2.52893
#
# column pt at index 22 is different
# batched: 1.9611384868621826
# c++: 3.61393
#
# column pt at index 23 is different
# batched: 3.613933801651001
# c++: 1.96114
#
# column pt at index 24 is different
# batched: 1.95423424243927
# c++: 2.18371
#
# column pt at index 25 is different
# batched: 2.1837146282196045
# c++: 1.95423
#
# column pt at index 40 is different
# batched: 2.002526044845581
# c++: 3.36119
#
# column pt at index 41 is different
# batched: 3.3611881732940674
# c++: 2.00253
#
# --------------- batch number 4 ----------------
# column z0 at index 1 is different
# batched: 1.7578125
# c++: 0.0
#
# column z0 at index 2 is different
# batched: 2.87109375
# c++: 0.0
#
# column z0 at index 3 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 4 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 5 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 6 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 7 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 8 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 9 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 10 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 11 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 12 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 13 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 14 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 15 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 16 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 17 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 18 is different
# batched: 21.0
# c++: 0.0
#
# column z0 at index 19 is different
# batched: 21.0
# c++: 1.75781
#
# column z0 at index 20 is different
# batched: 21.0
# c++: 2.87109
#
# column pt at index 1 is different
# batched: 2.8665130138397217
# c++: 0.0
#
# column pt at index 2 is different
# batched: 3.050001382827759
# c++: 0.0
#
# column pt at index 19 is different
# batched: 0.0
# c++: 2.86651
#
# column pt at index 20 is different
# batched: 0.0
# c++: 3.05

# %%
tc
# Out:
#       z0     pt  z0py   ptpy
# 0  -7.62   2.16 -7.62   2.16
# 1  -6.27   3.74 -6.27   3.74
# 2  -5.80   1.97 -5.80   1.97
# 3  -5.39   4.20 -5.39   4.20
# 4  -5.27   2.98 -5.27   2.98
# 5  -5.21   2.45 -5.21   2.45
# 6  -5.16   4.07 -5.16   4.07
# 7  -4.86   4.41 -4.86   4.41
# 8  -4.86   4.41 -4.86   4.41
# 9  -3.93   1.97 -3.93   1.97
# 10 -3.57   2.96 -3.57   2.96
# 11 -2.29   2.19 -2.29   2.19
# 12 -2.29   1.99 -2.29   1.99
# 13 -0.70   2.05 -0.70   2.05
# 14 -0.59   2.10 -0.59   2.10
# 15 -0.41   2.11 -0.41   2.24
# 16 -0.41   2.24 -0.41   2.11
# 17 -0.29   3.15 -0.29   3.15
# 18 -0.18   4.12 -0.18   4.12
# 19 -0.12   3.57 -0.12   5.36
# 20 -0.12   5.36 -0.12   3.57
# 21 -0.06   2.67 -0.06   2.67
# 22  0.00   2.11  0.00   2.11
# 23  0.06   2.44  0.06   2.44
# 24  0.12   4.38  0.12  12.62
# 25  0.12  12.62  0.12   4.38
# 26  0.18   2.40  0.18   2.40
# 27  0.23   2.12  0.23   2.12
# 28  0.29   2.62  0.29   6.12
# 29  0.29   6.12  0.29   2.62
# 30  0.35   2.53  0.35   2.53
# 31  0.47   2.03  0.47   2.03
# 32  0.59   2.32  0.59   2.32
# 33  0.59   3.58  0.59   2.14
# 34  0.59   2.14  0.59   3.58
# 35  0.70   3.29  0.70   3.29
# 36  0.76   4.74  0.76   4.74
# 37  0.82   2.88  0.82   2.88
# 38  1.35   2.23  1.35   2.23
# 39  1.70   2.97  1.70   2.97
# 40  1.76   2.72  1.76   2.72
# 41  3.40   2.13  3.40   2.13
# 42  3.81   2.55  3.81   2.55
# 43  4.10   2.25  4.10   2.25
# 44  4.80   2.21  4.80   2.21
# 45  5.51   2.13  5.51   2.13
# 46  5.62   2.01  5.62   2.01
# 47  5.68   2.06  5.68   2.06
# 48  5.86   2.14  5.86   2.14
# 49  7.97   2.61  7.97   2.61

# %%
tracks = tc.iloc[0:16]

# %%
tracks
# Out:
#       z0    pt  z0py  ptpy
# 0  -7.62  2.16 -7.62  2.16
# 1  -6.27  3.74 -6.27  3.74
# 2  -5.80  1.97 -5.80  1.97
# 3  -5.39  4.20 -5.39  4.20
# 4  -5.27  2.98 -5.27  2.98
# 5  -5.21  2.45 -5.21  2.45
# 6  -5.16  4.07 -5.16  4.07
# 7  -4.86  4.41 -4.86  4.41
# 8  -4.86  4.41 -4.86  4.41
# 9  -3.93  1.97 -3.93  1.97
# 10 -3.57  2.96 -3.57  2.96
# 11 -2.29  2.19 -2.29  2.19
# 12 -2.29  1.99 -2.29  1.99
# 13 -0.70  2.05 -0.70  2.05
# 14 -0.59  2.10 -0.59  2.10
# 15 -0.41  2.11 -0.41  2.24

# %%
np.cumsum(tracks['pt'].values)
# Out:
# array([ 2.16,  5.9 ,  7.87, 12.07, 15.05, 17.5 , 21.57, 25.98, 30.38,
#        32.35, 35.31, 37.5 , 39.49, 41.54, 43.65, 45.76])

# %%
db.prefix_sum(tracks['pt'].values)
# Out:
# array([ 0.  ,  2.16,  5.9 ,  7.87, 12.07, 15.05, 17.5 , 21.57, 25.98,
#        30.38, 32.35, 35.31, 37.5 , 39.49, 41.54, 43.65])
